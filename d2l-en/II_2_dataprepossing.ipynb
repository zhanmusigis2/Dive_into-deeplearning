# %%
import os

# %%
#reading the dataset
os.makedirs(os.path.join("..","data"),exist_ok=True)

# %%
data_file=os.path.join("..","data","train.csv")

# %%
with open (data_file,"w") as f:
    f.write("""
NumRooms, RoofType, Price
NA,NA,127500
2,NA, 106000
4,Slate,178100
NA,NA,140000""")

# %%
import pandas as pd

# %%
data=pd.read_csv(data_file)

# %%
inputs, targets=data.iloc[:,0:2], data.iloc[:,2]

# %%
inputs=pd.get_dummies(inputs,dummy_na=True)

# %%
inputs=inputs.fillna(inputs.mean())

# %%
inputs
# Out:
#    NumRooms   RoofType_Slate   RoofType_nan
# 0       3.0            False           True
# 1       2.0            False           True
# 2       4.0             True          False
# 3       3.0            False           True

# %%
import torch

# %%
torch.from_numpy(inputs.to_numpy(dtype=float))
#so basically, there are two ways to process the initial data, with NAN, one is delete and another is fill
# Out:
# tensor([[3., 0., 1.],
#         [2., 0., 1.],
#         [4., 1., 0.],
#         [3., 0., 1.]], dtype=torch.float64)
